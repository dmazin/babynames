# %%
import pandas as pd

# %matplotlib inline

import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = [10, 6]

# %% [markdown]
# # Figuring out how to calculate simpson

# %%
df = pd.io.parsers.read_csv('data/yob2016.txt', header=None)

# %%
df.head()
# Out:
#           0  1      2
# 0      Emma  F  19414
# 1    Olivia  F  19246
# 2       Ava  F  16237
# 3    Sophia  F  16070
# 4  Isabella  F  14722

# %%
df_m = df[df[1].str.match('M')]

# %%
df_m.head()
# Out:
#              0  1      2
# 18757     Noah  M  19015
# 18758     Liam  M  18138
# 18759  William  M  15668
# 18760    Mason  M  15192
# 18761    James  M  14776

# %%
total_m = df_m[2].values.sum()

# %%
# Simpson
1 - sum([x * (x - 1) for x in df_m[2].values]) / (total_m * (total_m - 1))
# Out:
# 0.99745548762493041

# %% [markdown]
# # Simpson national all years (boys)

# %%
def get_simpson(year, sex):
    df = pd.io.parsers.read_csv('data/yob{}.txt'.format(year), header=None)
    df_m = df[df[1].str.match(sex)]
    total_m = df_m[2].values.sum()
    return 1 - sum([x * (x - 1) for x in df_m[2].values]) / (total_m * (total_m - 1))

# %%
years = range(1930, 2017)
diversities = [get_simpson(year, 'M') for year in years]

# %%
s = pd.Series(diversities, years)

# %%
s.head()
# Out:
# 1930    0.984146
# 1931    0.984114
# 1932    0.984295
# 1933    0.984375
# 1934    0.984436
# dtype: float64

# %%
s.plot()

# %% [markdown]
# # Simpson national all years (girls)

# %%
diversities_f = [get_simpson(year, 'F') for year in years]

# %%
s_f = pd.Series(diversities_f, years)

# %%
s_f.plot()

# %% [markdown]
# # Girls vs boys

# %%
s.plot()
s_f.plot()

# Girls is the more diverse one

# %% [markdown]
# # Adding birthcount to the graph

# %%
def get_total_births(year, sex):
    df = pd.io.parsers.read_csv('data/yob{}.txt'.format(year), header=None)
    df_m = df[df[1].str.match(sex)]
    return df_m[2].values.sum()

# %%
births_m = [get_total_births(year, 'M') for year in years]
births_f = [get_total_births(year, 'F') for year in years]

# %%
plt.figure(1)
plt.subplot(211)
births_m_line = plt.plot(years, births_m, label='M')
births_f_line = plt.plot(years, births_f, label='F')
plt.legend(handles=[births_m_line[0], births_f_line[0]])

plt.subplot(212)
diversities_m_line = plt.plot(years, diversities, label='M')
diversities_f_line = plt.plot(years, diversities_f, label='F')
plt.legend(handles=[diversities_m_line[0], diversities_f_line[0]])
plt.show()

# %% [markdown]
# # Next: plot out immigration?
